# %% [markdown]
# #### REGRESSION MODEL
# The goal of this project was to predict the remaining useful life of turbo fan engines, but in last week i converted it into a classification task, where the accuray of the model was failrly good. But in this model i'll treat this as a regression problem. The goal will be to train a ML model without any EDA or hyperparameter tunings and see how accurate does it predict the RUL. If the predictions will turn out to be faulty or unreliable, i'll move on to do the Exploratory Data analysis, feature selection part and hyperparameter tuning.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics

# %%
df = pd.read_csv('RUL_Train_1.csv')

# %%
df.head()
# Out:
#    Cycle  OpSet1  OpSet2  OpSet3  SensorMeasure1  SensorMeasure2  \
# 0      1 -0.0007 -0.0004   100.0          518.67          641.82
# 1      2  0.0019 -0.0003   100.0          518.67          642.15
# 2      3 -0.0043  0.0003   100.0          518.67          642.35
# 3      4  0.0007  0.0000   100.0          518.67          642.35
# 4      5 -0.0019 -0.0002   100.0          518.67          642.37
#
#    SensorMeasure3  SensorMeasure4  SensorMeasure5  SensorMeasure6  ...  \
# 0         1589.70         1400.60           14.62           21.61  ...
# 1         1591.82         1403.14           14.62           21.61  ...
# 2         1587.99         1404.20           14.62           21.61  ...
# 3         1582.79         1401.87           14.62           21.61  ...
# 4         1582.85         1406.22           14.62           21.61  ...
#
#    SensorMeasure13  SensorMeasure14  SensorMeasure15  SensorMeasure16  \
# 0          2388.02          8138.62           8.4195             0.03
# ...

# %% [markdown]
# ##### Gives data on how many engine's Run-to-failure data is available
# Run-to-failure data is available if Remaining Usefull Life (RUL) of engine is 0

# %%
df[df['RUL']==0]
# Out:
#        Cycle  OpSet1  OpSet2  OpSet3  SensorMeasure1  SensorMeasure2  \
# 191      192  0.0009 -0.0000   100.0          518.67          643.54
# 478      287 -0.0005  0.0006   100.0          518.67          643.85
# 657      179  0.0012  0.0000   100.0          518.67          643.51
# 846      189 -0.0024 -0.0002   100.0          518.67          644.53
# 1115     269  0.0022  0.0003   100.0          518.67          643.46
# ...      ...     ...     ...     ...             ...             ...
# 19887    336 -0.0031 -0.0005   100.0          518.67          643.74
# 20089    202  0.0014  0.0001   100.0          518.67          643.79
# 20245    156  0.0077 -0.0003   100.0          518.67          643.02
# 20430    185 -0.0019 -0.0004   100.0          518.67          643.93
# 20630    200 -0.0032 -0.0005   100.0          518.67          643.85
#
#        SensorMeasure3  SensorMeasure4  SensorMeasure5  SensorMeasure6  ...  \
# ...

# %% [markdown]
# #### Train Test Split

# %%
X = df.iloc[:, 0:-1]
y = df.iloc[:, -1]


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle=False)

# %% [markdown]
# #### Random Forest Regression

# %%
# Initializing the Model with arbitary parameters
regressor = RandomForestRegressor()

# Training the model
regressor.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# #### Train Plot

# %%
# Using the trained model to check the Training data
y_pred = regressor.predict(X_train)

# Plot the train data
plt.scatter(X_train['Cycle'][0:192],y_pred[0:192])
plt.scatter(X_train['Cycle'][0:192],np.array(y_train)[0:192])
plt.ylabel('RUL')
plt.xlabel('CYCLE')
plt.legend(['Prediction', 'Actual'], loc='upper right')
plt.show()


print('RMSE on Train set:', np.sqrt(metrics.mean_squared_error(y_train ,y_pred)))
# Out:
# RMSE on Train set: 12.087639852473364

# %% [markdown]
# #### Test Plot

# %%
# Using the trained model to check the Test data
y_pred = regressor.predict(X_test)

print('RMSE on Test set:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# Plotting the test data
plt.scatter(X_test['Cycle'][100:200],y_pred[100:200])
plt.scatter(X_test['Cycle'][100:200],np.array(y_test)[100:200])
plt.legend(['Prediction', 'Actual'], loc='upper right')
plt.ylabel('RUL')
plt.xlabel('CYCLES')
plt.show()
# Out:
# RMSE on Test set: 49.16564477651323

# %%
regressor = LogisticRegression()
regressor.fit(X_train, y_train)
# Out:
# c:\Users\singh\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# #### Train Plot

# %%
# Using the trained model to check the Training data
y_pred = regressor.predict(X_train)

# Plot the train data
plt.scatter(X_train['Cycle'][0:192],y_pred[0:192])
plt.scatter(X_train['Cycle'][0:192],np.array(y_train)[0:192])
plt.ylabel('RUL')
plt.xlabel('CYCLE')
plt.legend(['Prediction', 'Actual'], loc='upper right')
plt.show()


print('RMSE on Train set:', np.sqrt(metrics.mean_squared_error(y_train ,y_pred)))
# Out:
# RMSE on Train set: 43.89298047355815

# %% [markdown]
# #### Test Plot

# %%
# Using the trained model to check the Test data
y_pred = regressor.predict(X_test)

print('RMSE on Test set:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# Plotting the test data
plt.scatter(X_test['Cycle'][100:200],y_pred[100:200])
plt.scatter(X_test['Cycle'][100:200],np.array(y_test)[100:200])
plt.legend(['Prediction', 'Actual'], loc='upper right')
plt.ylabel('RUL')
plt.xlabel('CYCLES')
plt.show()
# Out:
# RMSE on Test set: 68.99697812270783
